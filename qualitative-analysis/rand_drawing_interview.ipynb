# %%
import pandas as pd
import numpy as np
import json
import random
from numpy.random import randint
import os
import shutil

# %%
print(os.getcwd())
os.chdir("c:\\Users\\ruppr\\OneDrive - Universität Mannheim\\Team Project\\hubsim\\qualitative-analysis")
# Out:
# c:\Users\ruppr\OneDrive - Universität Mannheim\Team Project\hubsim\qualitative-analysis

# %%
share = 0.08
conv_folder = "../single-factor-experiments/bagel-dpo-34b-v0.2-bagel-dpo-34b-v0.2/"
conv_folder = "../single-factor-experiments/bagel-dpo-34b-v0.2-Yi-34B-Chat/"
conv_folder = "../single-factor-experiments/Yi-34B-Chat-bagel-dpo-34b-v0.2/"
conv_folder = "../single-factor-experiments/Yi-34B-Chat-Yi-34B-Chat/"

rand_conv_folder = "bagel-dpo-34b-v0.2-bagel-dpo-34b-v0.2_interview/"
rand_conv_folder = "bagel-dpo-34b-v0.2-Yi-34B-Chat_interview/"
rand_conv_folder = "Yi-34B-Chat-bagel-dpo-34b-v0.2_interview/"
rand_conv_folder = "Yi-34B-Chat-Yi-34B-Chat_interview/"

interview_folder = "../COMPLETE_bagel-dpo-34b-v0.2-bagel-dpo-34b-v0.2/"
interview_folder = "../COMPLETE_bagel-dpo-34b-v0.2-Yi-34B-Chat/"
interview_folder = "../COMPLETE_Yi-34B-Chat-bagel-dpo-34b-v0.2/"
interview_folder = "../COMPLETE_Yi-34B-Chat-Yi-34B-Chat/"

for i in os.listdir(conv_folder):
    no_draws = round(len(os.listdir(conv_folder + i))*share)
    print(no_draws)
    draw_conv = random.sample(range(0, len(os.listdir(conv_folder + i))), no_draws)
    print(draw_conv)
    if not os.path.exists(rand_conv_folder + i):
        os.makedirs(rand_conv_folder + i)
    else:
       shutil.rmtree(rand_conv_folder + i)           # Removes all the subdirectories!
       os.makedirs(rand_conv_folder + i)
    for file in draw_conv:
        # construct full file path
        source = conv_folder + i + "/" + os.listdir(conv_folder+i)[file]
        destination = rand_conv_folder + i + "/" + os.listdir(conv_folder+i)[file]
        # move file
        shutil.copytree(source, destination,dirs_exist_ok=True)
        print('Copied:', file)
# Out:
# 2
# [23, 8]
# Copied: 23
# Copied: 8
# 2
# [23, 3]
# Copied: 23
# Copied: 3
# 0
# []
# 2
# [6, 7]
# Copied: 6
# Copied: 7
# 2
# [22, 23]
# Copied: 22
# Copied: 23
# 2
# [22, 23]
# Copied: 22
# Copied: 23
# 2
# [8, 9]
# Copied: 8
# Copied: 9
# 2
# [5, 22]
# Copied: 5
# Copied: 22
# 2
# [14, 5]
# Copied: 14
# Copied: 5
# 2
# [9, 18]
# Copied: 9
# Copied: 18
# 2
# [3, 9]
# Copied: 3
# Copied: 9
# 2
# [21, 6]
# Copied: 21
# Copied: 6
# 2
# [0, 10]
# Copied: 0
# Copied: 10
# 2
# [8, 22]
# Copied: 8
# Copied: 22
# 2
# [21, 14]
# Copied: 21
# Copied: 14
# 2
# [4, 1]
# Copied: 4
# Copied: 1
# 2
# [8, 1]
# Copied: 8
# Copied: 1
# 0
# []
# 2
# [15, 19]
# Copied: 15
# Copied: 19
# 2
# [22, 15]
# Copied: 22
# Copied: 15

# %%
rows_list =[]

for i in os.listdir(rand_conv_folder):
    name = [i] * len(os.listdir(rand_conv_folder + i))
    identifier = os.listdir(rand_conv_folder + i)
    label = ["nan"] * len(os.listdir(rand_conv_folder + i))
    text = []
    for item in os.listdir(rand_conv_folder + i):
        with open(rand_conv_folder + i + "/" + item + "/" +"conversation.json") as f:
            d = json.load(f)
            text.append(d)
    rows_list.append([name, identifier, text, label])
    

    
print(rows_list)
df_to_label = pd.DataFrame(rows_list, columns=["name", "identifier", "text", "label"]).reset_index()
df_to_label = df_to_label.explode(["name", "identifier", "text", "label"])

selected_conversations = list(df_to_label["identifier"])
len(set(selected_conversations)) # 38 unique observations
# Out:
# [[['landlord-Yi-34B-Chat-Emilia Müller from Germany-Yi-34B-Chat-Duisburg-20240207', 'landlord-Yi-34B-Chat-Emilia Müller from Germany-Yi-34B-Chat-Duisburg-20240207'], ['8822823c-72d3-4285-a4ea-f27631378dc3', 'f29a9ec3-0d68-4348-b851-b54cf501a8c0'], [[{'content': "Hello Mister Schmidt, my name is Emilia Müller from Germany. Thanks for inviting me to see the apartment in Duisburg. Let's talk about the rental price.", 'role': 'user', 'name': 'Emilia Müller from Germany'}, {'content': "Hello Emilia, it's a pleasure to meet you. I'm sure you'll find my apartment quite comfortable and convenient. So, what is your budget for renting this place?", 'role': 'user', 'name': 'Peter Schmidt from Germany'}, {'content': "Well, Mr. Schmidt, I'm a student, and I'm looking for a place that's not only close to the university but also affordable. I'd like to keep the rent as low as possible, considering my financial situation. What's the lowest price you can offer for this apartment?", 'role': 'user', 'name': 'Emilia Müller from Germany'}, {'content': "As a landlord, I always aim to provide the best living space for my tenants while also ensuring a fair return on my investment. Given the prime location and the quality of the apartment, I'm looking at a price range that reflects its value. However, considering your student status, I'm willing to negotiate a bit. How does 1000 Euros per month sound to you?", 'role': 'user', 'name': 'Peter Schmidt from Germany'}, {'content': "Mr. Schmidt, I appreciate your willingness to negotiate. However, 1000 Euros is still quite high for me as a student. I'm hoping to find something more in line with my budget. Could we possibly discuss a lower price?", 'role': 'user', 'name': 'Emilia Müller from Germany'}, {'content': "Of course, Emilia. I understand that every tenant has their own budget. Let's see if we can find a price that works for both of us. How about 950 Euros per month? I think that's a fair offer considering the amenities and the location. What do you think?", 'role': 'user', 'name': 'Peter Schmidt from Germany'}, {'content': "950 Euros is more in line with what I had in mind. It's still a bit higher than I would like, but it's a reasonable offer. Could we perhaps discuss some additional terms or concessions that might make the rent more manageable?", 'role': 'user', 'name': 'Emilia Müller from Germany'}, {'content': "Certainly, Emilia. I'm open to discussing additional terms. However, I must remind you that this apartment is brand new and in a highly sought-after area, which justifies the price. Nevertheless, I'm willing to listen to any suggestions you may have. Would you be interested in a longer lease term, for example? This could potentially result in a lower monthly rate.", 'role': 'user', 'name': 'Peter Schmidt from Germany'}, {'content': 'A longer lease term could indeed be an interesting option. How would that affect the monthly rate? Could we negotiate a lower monthly rent if I sign a two-year lease, for instance?', 'role': 'user', 'name': 'Emilia Müller from Germany'}, {'content': 'Certainly, Emilia. A longer lease term could potentially lead to a lower monthly rent. How does a two-year lease at 900 Euros per month sound to you? This would represent a significant discount for the length of the contract. Would you be interested in such an arrangement?', 'role': 'user', 'name': 'Peter Schmidt from Germany'}, {'content': '900 Euros per month for a two-year lease is an offer I would definitely consider. It aligns well with my budget and the stability of a long-term lease would be beneficial for me as a student. Can you provide more details about the terms of the lease?', 'role': 'user', 'name': 'Emilia Müller from Germany'}, {'content': "Certainly, Emilia. A two-year lease at 900 Euros per month would be a binding contract, meaning you would commit to renting the apartment for the full duration of the lease. During this time, you would not be able to terminate the lease early without incurring a ...
# 38

# %%
# append interviews: look for identifier and append the two interviews
interviews_list =[]

for i in os.listdir(interview_folder):
    name_folder = os.path.join(interview_folder, i)
    for identificator in os.listdir(name_folder):
        identificator_folder = os.path.join(name_folder, identificator)
        identifier_interview = identificator
        name_interview = i        
        #for item in os.listdir(identificator_folder):
        for person in ["renter", "landlord"]:
            text = []
            try:
                with open(identificator_folder  + "/" + person + "/" + "conversation.json") as f:
                    d = json.load(f)
                    text.append(d)
                interviews_list.append([name_interview, identifier_interview, text, person])
                print("successfully appended: ", identificator_folder  + "/" + person + "/" + "conversation.json")
            except Exception as e:
                print(f"An error occured: {e}. Trying again.")
                interviews_list.append([name_interview, identifier_interview, "nan", person])

df_interviews = pd.DataFrame(interviews_list, columns=["name_interview", "identifier_interview", "text", "person"]).reset_index()
df_interviews_renter = df_interviews[df_interviews["person"] == "renter"]
df_interviews_renter.rename(columns={'text':'interview_renter'}, inplace=True)
#df_interviews_renter["successfull_renter"] = ["nan"] * len(df_interviews_renter)
labels_renter = ["successfull_renter", "agent_confusion_renter",
                      "format_change_renter", "counterintuitive_renter",
                      "inc_termination_renter", "secret_share_renter",
                      "inc_price_acceptance_renter", "inc_refusal_renter"]
df_interviews_renter[labels_renter] = pd.DataFrame(np.nan, index = np.arange(len(df_interviews_renter)), columns=labels_renter) 

labels_landlord = ["successfull_landlord", "agent_confusion_landlord",
                      "format_change_landlord", "counterintuitive_landlord",
                      "inc_termination_landlord", "secret_share_landlord",
                      "inc_price_acceptance_landlord", "inc_refusal_landlord"]
df_interviews_landlord = df_interviews[df_interviews["person"] == "landlord"]
df_interviews_landlord.rename(columns={'text':'interview_landlord'}, inplace=True)
#df_interviews_landlord["label_landlord"] = ["nan"] * len(df_interviews_landlord)
df_interviews_landlord[labels_landlord] = pd.DataFrame(np.nan, index = np.arange(len(df_interviews_landlord)), columns=labels_landlord)


#df_interviews = df_to_label.explode(["name", "identifier", "text", "person"])
print("Length of interview df: ", len(df_interviews))
print("Length of renter interview df: ", len(df_interviews_renter))
print("Length of landlord interview df: ", len(df_interviews_landlord))
df_interviews_landlord
# Out:
# successfully appended:  ../COMPLETE_Yi-34B-Chat-Yi-34B-Chat/landlord-Yi-34B-Chat-Emilia Müller from Germany-Yi-34B-Chat-Duisburg-20240207\08572bc2-b5ec-4c3b-ac26-5d6b647c2429/renter/conversation.json
# successfully appended:  ../COMPLETE_Yi-34B-Chat-Yi-34B-Chat/landlord-Yi-34B-Chat-Emilia Müller from Germany-Yi-34B-Chat-Duisburg-20240207\08572bc2-b5ec-4c3b-ac26-5d6b647c2429/landlord/conversation.json
# successfully appended:  ../COMPLETE_Yi-34B-Chat-Yi-34B-Chat/landlord-Yi-34B-Chat-
py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_interviews_renter[labels_renter] = pd.DataFrame(np.nan, index = np.arange(len(df_interviews_renter)), columns=labels_renter)
# C:\Users\ruppr\AppData\Local\Temp\ipykernel_24036\738313210.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_interviews_renter[labels_renter] = pd.DataFrame(np.nan, index = np.arange(len(df_interviews_renter)), columns=labels_renter)
# C:\Users\ruppr\AppData\Local\Temp\ipykernel_24036\738313210.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_interviews_renter[labels_renter] = pd.DataFrame(np.nan, index = np.arange(len(df_interviews_renter)), columns=labels_renter)
# C:\Users\ruppr\AppData\Local\Temp\ipykernel_24036\738313210.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_interviews_renter[labels_renter] = pd.DataFrame(np.nan, index = np.arange(len(df_interviews_renter)), columns=labels_renter)
# C:\Users\ruppr\AppData\Local\Temp\ipykernel_24036\738313210.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_interviews_renter[labels_renter] = pd.DataFrame(np.nan, index = np.arange(len(df_interviews_renter)), columns=labels_renter)
# C:\Users\ruppr\AppData\Local\Temp\ipykernel_24036\738313210.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_interviews_renter[labels_renter] = pd.DataFrame(np.nan, index = np.arange(len(df_interviews_renter)), columns=labels_renter)
# C:\Users\ruppr\AppData\Local\Temp\ipykernel_24036\738313210.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_interviews_renter[labels_renter] = pd.DataFrame(np.nan, index = np.arange(len(df_interviews_renter)), columns=labels_renter)
# C:\Users\ruppr\AppData\Local\Temp\ipykernel_24036\738313210.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_interviews_landlord.rename(columns={'text':'interview_landlord'}, inplace=True)
# C:\Users\ruppr\AppData\Local\Temp\ipykernel_24036\738313210.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_interviews_landlord[labels_landlord] = pd.DataFrame(np.nan, index = np.arange(len(df_interviews_landlord)), columns=labels_landlord)
# C:\Users\ruppr\AppData\Local\Temp\ipykernel_24036\738313210.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_interviews_landlord[labels_landlord] = pd.DataFrame(np.nan, index = np.arange(len(df_interviews_landlord)), columns=labels_landlord)
# C:\Users\ruppr\AppData\Local\Temp\ipykernel_24036\738313210.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_interviews_landlord[labels_landlord] = pd.DataFrame(np.nan, index = np.arange(len(df_interviews_landlord)), columns=labels_landlord)
# C:\Users\ruppr\AppData\Local\Temp\ipykernel_24036\738313210.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_interviews_landlord[labels_landlord] = pd.DataFrame(np.nan, index = np.arange(len(df_interviews_landlord)), columns=labels_landlord)
# C:\Users\ruppr\AppData\Local\Temp\ipykernel_24036\738313210.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_interviews_landlord[labels_landlord] = pd.DataFrame(np.nan, index = np.arange(len(df_interviews_landlord)), columns=labels_landlord)
# C:\Users\ruppr\AppData\Local\Temp\ipykernel_24036\738313210.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_interviews_landlord[labels_landlord] = pd.DataFrame(np.nan, index = np.arange(len(df_interviews_landlord)), columns=labels_landlord)
# C:\Users\ruppr\AppData\Local\Temp\ipykernel_24036\738313210.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_interviews_landlord[labels_landlord] = pd.DataFrame(np.nan, index = np.arange(len(df_interviews_landlord)), columns=labels_landlord)
# C:\Users\ruppr\AppData\Local\Temp\ipykernel_24036\738313210.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_interviews_landlord[labels_landlord] = pd.DataFrame(np.nan, index = np.arange(len(df_interviews_landlord)), columns=labels_landlord)
#      index                                     name_interview  \
# 1        1  landlord-Yi-34B-Chat-Emilia Müller from German...
# 3        3  landlord-Yi-34B-Chat-Emilia Müller from German...
# 5        5  landlord-Yi-34B-Chat-Emilia Müller from German...
# 7        7  landlord-Yi-34B-Chat-Emilia Müller from German...
# 9        9  landlord-Yi-34B-Chat-Emilia Müller from German...
# ..     ...                                                ...
# 891    891  landlord-Yi-34B-Chat-Yi-Nuo Wang from China-Yi...
# 893    893  landlord-Yi-34B-Chat-Yi-Nuo Wang from China-Yi...
# 895    895  landlord-Yi-34B-Chat-Yi-Nuo Wang from China-Yi...
# 897    897  landlord-Yi-34B-Chat-Yi-Nuo Wang from China-Yi...
# 899    899  landlord-Yi-34B-Chat-Yi-Nuo Wang from China-Yi...
#
#                      identifier_interview  \
# 1    08572bc2-b5ec-4c3b-ac26-5d6b647c2429
# 3    0ec17f2f-98a8-4ebd-aab2-11f5178dd7e2
# 5    1ca6ad24-e82f-436a-9380-c70c2443bafb
# 7    3bec85f2-ecba-4c08-a254-5bd648856525
# 9    47538df9-7930-4e52-b0c8-f15c709bcf37
# ..                                    ...
# 891  ea87229e-48ea-466f-ae2f-71ddb93912b7
# 893  ec24cbdc-d8ca-4bea-ad75-8aa0d1325ede
# 895  f30ee210-9311-4b87-a929-e5da0bb1bb08
# 897  f57f49e0-8a9f-4977-968d-448a5b6f9c71
# 899  f59976fc-dd78-4126-b7c5-d003b20e2d19
#
#                                     interview_landlord    person  \
# 1    [[{'content': 'What is your name?', 'role': 'u...  landlord
# 3    [[{'content': 'What is your name?', 'role': 'u...  landlord
# 5    [[{'content': 'What is your name?', 'role': 'u...  landlord
# 7    [[{'content': 'What is your name?', 'role': 'u...  landlord
# 9    [[{'content': 'What is your name?', 'role': 'u...  landlord
# ..                                                 ...       ...
# 891  [[{'content': 'What is your name?', 'role': 'u...  landlord
# 893  [[{'content': 'What is your name?', 'role': 'u...  landlord
# 895  [[{'content': 'What is your name?', 'role': 'u...  landlord
# 897  [[{'content': 'What is your name?', 'role': 'u...  landlord
# 899  [[{'content': 'What is your name?', 'role': 'u...  landlord
#
#      successfull_landlord  agent_confusion_landlord  format_change_landlord  \
# 1                     NaN                       NaN                     NaN
# 3                     NaN                       NaN                     NaN
# 5                     NaN                       NaN                     NaN
# 7                     NaN                       NaN                     NaN
# 9                     NaN                       NaN                     NaN
# ..                    ...                       ...                     ...
# 891                   NaN                       NaN                     NaN
# 893                   NaN                       NaN                     NaN
# 895                   NaN                       NaN                     NaN
# 897                   NaN                       NaN                     NaN
# 899                   NaN                       NaN                     NaN
#
#      counterintuitive_landlord  inc_termination_landlord  \
# 1                          NaN                       NaN
# 3                          NaN                       NaN
# 5                          NaN                       NaN
# 7                          NaN                       NaN
# 9                          NaN                       NaN
# ..                         ...                       ...
# 891                        NaN                       NaN
# 893                        NaN                       NaN
# 895                        NaN                       NaN
# 897                        NaN                       NaN
# 899                        NaN                       NaN
#
#      secret_share_landlord  inc_price_acceptance_landlord  \
# 1                      NaN                            NaN
# 3                      NaN                            NaN
# 5                      NaN                            NaN
# 7                      NaN                            NaN
# 9                      NaN                            NaN
# ..                     ...                            ...
# 891                    NaN                            NaN
# 893                    NaN                            NaN
# 895                    NaN                            NaN
# 897                    NaN                            NaN
# 899                    NaN                            NaN
#
#      inc_refusal_landlord
# 1                     NaN
# 3                     NaN
# 5                     NaN
# 7                     NaN
# 9                     NaN
# ..                    ...
# 891                   NaN
# 893                   NaN
# 895                   NaN
# 897                   NaN
# 899                   NaN
#
# [450 rows x 13 columns]

# %%
# merge interview and conversations to one df
print("Length of Interview df: ", len(df_interviews))
print("Length of Conversation df: ", len(df_to_label))
full_to_label = df_to_label.merge(df_interviews_renter, how="left", left_on=["name", "identifier"], right_on= ["name_interview","identifier_interview"])
full_to_label = full_to_label.merge(df_interviews_landlord, how="left", left_on=["name", "identifier"], right_on= ["name_interview","identifier_interview"], indicator=True)
print("Length of full df: ", len(full_to_label))
display(full_to_label)
# Out:
# Length of Interview df:  900
# Length of Conversation df:  38
# Length of full df:  38
#     index_x                                               name  \
# 0         0  landlord-Yi-34B-Chat-Emilia Müller from German...
# 1         0  landlord-Yi-34B-Chat-Emilia Müller from German...
# 2         1  landlord-Yi-34B-Chat-Emilia Müller from German...
# 3         1  landlord-Yi-34B-Chat-Emilia Müller from German...
# 4         2                                                NaN
# 5         3  landlord-Yi-34B-Chat-Emilia Müller from German...
# 6         3  landlord-Yi-34B-Chat-Emilia Müller from German...
# 7         4  landlord-Yi-34B-Chat-Farhad Abbasi from Iran-Y...
# 8         4  landlord-Yi-34B-Chat-Farhad Abbasi from Iran-Y...
# 9         5  landlord-Yi-34B-Chat-Farhad Abbasi from Iran-Y...
# 10        5  landlord-Yi-34B-Chat-Farhad Abbasi from Iran-Y...
# 11        6  landlord-Yi-34B-Chat-Farhad Abbasi from Iran-Y...
# 12        6  landlord-Yi-34B-Chat-Farhad Abbasi from Iran-Y...
# 13        7  landlord-Yi-34B-Chat-Haoyu Wang from China-Yi-...
# 14        7  landlord-Yi-34B-Chat-Haoyu Wang from China-Yi-...
# 15        8  landlord-Yi-34B-Chat-Haoyu Wang from China-Yi-...
# 16        8  landlord-Yi-34B-Chat-Haoyu Wang from China-Yi-...
# 17        9  landlord-Yi-34B-Chat-Haoyu Wang from China-Yi-...
# 18        9  landlord-Yi-34B-Chat-Haoyu Wang from China-Yi-...
# 19       10  landlord-Yi-34B-Chat-Maryam Abbasi from Iran-Y...
# 20       10  landlord-Yi-34B-Chat-Maryam Abbasi from Iran-Y...
# 21       11  landlord-Yi-34B-Chat-Maryam Abbasi from Iran-Y...
# 22       11  landlord-Yi-34B-Chat-Maryam Abbasi from Iran-Y...
# 23       12  landlord-Yi-34B-Chat-Maryam Abbasi from Iran-Y...
# 24       12  landlord-Yi-34B-Chat-Maryam Abbasi from Iran-Y...
# 25       13  landlord-Yi-34B-Chat-Max Müller from Germany-Y...
# 26       13  landlord-Yi-34B-Chat-Max Müller from Germany-Y...
# 27       14  landlord-Yi-34B-Chat-Max Müller from Germany-Y...
#
#                                                  text label  index_y  \
# 0   [{'content': 'Hello Mister Schmidt, my name is...   nan     16.0
# 1   [{'content': 'Hello Mister Schmidt, my name is...   nan     46.0
# 2   [{'content': 'Hello Mister Schmidt, my name is...   nan     56.0
# 3   [{'content': 'Hello Mister Schmidt, my name is...   nan     94.0
# 4                                                 NaN   NaN      NaN
# 5   [{'content': 'Hello Mister Schmidt, my name is...   nan    112.0
# 6   [{'content': 'Hello Mister Schmidt, my name is...   nan    114.0
# 7   [{'content': 'Hello Mister Schmidt, my name is...   nan    194.0
# 8   [{'content': 'Hello Mister Schmidt, my name is...   nan    196.0
# 9   [{'content': 'Hello Mister Schmidt, my name is...   nan    244.0
# 10  [{'content': 'Hello Mister Schmidt, my name is...   nan    246.0
# 11  [{'content': 'Hello Mister Schmidt, my name is...   nan    266.0
# 12  [{'content': 'Hello Mister Schmidt, my name is...   nan    268.0
# 13  [{'content': 'Hello Mister Schmidt, my name is...   nan    310.0
# 14  [{'content': 'Hello Mister Schmidt, my name is...   nan    344.0
# 15  [{'content': 'Hello Mister Schmidt, my name is...   nan    360.0
# 16  [{'content': 'Hello Mister Schmidt, my name is...   nan    378.0
# 17  [{'content': 'Hello Mister Schmidt, my name is...   nan    418.0
# 18  [{'content': 'Hello Mister Schmidt, my name is...   nan    436.0
# 19  [{'content': 'Hello Mister Schmidt, my name is...   nan    456.0
# 20  [{'content': 'Hello Mister Schmidt, my name is...   nan    468.0
# 21  [{'content': 'Hello Mister Schmidt, my name is...   nan    512.0
# 22  [{'content': 'Hello Mister Schmidt, my name is...   nan    542.0
# 23  [{'content': 'Hello Mister Heine, my name is M...   nan    550.0
# 24  [{'content': 'Hello Mister Heine, my name is M...   nan    570.0
# 25  [{'content': 'Hello Mister Schmidt, my name is...   nan    616.0
# 26  [{'content': 'Hello Mister Schmidt, my name is...   nan    644.0
# 27  [{'content': 'Hello Mister Schmidt, my name is...   nan    678.0
# 28  [{'content': 'Hello Mister Schmidt, my name is...   nan    692.0
# 29  [{'content': 'Hello Mister Schmidt, my name is...   nan    702.0
# 30  [{'content': 'Hello Mister Schmidt, my name is...   nan    708.0
# 31  [{'content': 'Hello Mister Schmidt, my name is...   nan    752.0
# 32  [{'content': 'Hello Mister Schmidt, my name is...   nan    766.0
# 33                                                NaN   NaN      NaN
# 34  [{'content': 'Hello Mister Schmidt, my name is...   nan    830.0
# 35  [{'content': 'Hello Mister Schmidt, my name is...   nan    838.0
# 36  [{'content': 'Hello Mister Schmidt, my name is...   nan    880.0
# 37  [{'content': 'Hello Mister Schmidt, my name is...   nan    894.0
#
#                                      name_interview_x  \
# 0   landlord-Yi-34B-Chat-Emilia Müller from German...
# 1   landlord-Yi-34B-Chat-Emilia Müller from German...
# 2   landlord-Yi-34B-Chat-Emilia Müller from German...
# 3   landlord-Yi-34B-Chat-Emilia Müller from German...
# 4                                                 NaN
# 5   landlord-Yi-34B-Chat-Emilia Müller from German...
# 6   landlord-Yi-34B-Chat-Emilia Müller from German...
# 14  f08ee521-7b46-489f-b547-f01ff698ae48
# 15  1c7e6600-1fb4-4a66-a96f-6c2768b6c5b1
# 16  8161784a-32a4-4523-ad48-0255f80fc95d
# 17  6719a725-024b-49e0-9178-1a25fa90def4
# 18  d09d5369-6c01-49d1-9a02-09ddba47d5df
# 19  18406332-18ac-4ffa-a387-6b83745bf341
# 20  57a39714-4ed3-4815-b5c5-51bf1c63a994
# 21  3914f7cb-358d-402a-93bb-9c027b2db1ba
# 22  bcddde6e-1890-46d1-8047-938381443a98
# 23  04e66956-56ce-4f0c-a2ba-c7a4df3e2f8f
# 24  9cc212f1-5b7c-4f28-bf40-9ba4d27a1c0e
# 25  5375f001-9c1e-4b7d-bc4b-0ca158a5832a
# 26  d6480050-4d2b-4174-9ad6-cbf0e9d8dfc6
# 27  72b7cea6-14d6-469a-b238-64f699f5b43f
# 28  e87a8f02-3aaf-4c04-b113-e9b6c1b8afe8
# 29  096a6fd2-8d75-4168-a812-5675187b4027
# 30  3c2293b4-714c-4f93-bb38-a7afca8655b8
# 31  15cf9269-bdf3-407b-ba66-cf2b8366eae3
# 32  557c7fbb-e813-40a7-844e-0049fd40984a
# 33                                   NaN
# 34  9ecb3e3b-0e62-40d5-8d72-cfcd84566b97
# 35  c55aa41d-e465-441d-9b76-3d52136138b9
# 36  971233cc-5b15-44dd-b347-92aa528a3e76
# 37  f30ee210-9311-4b87-a929-e5da0bb1bb08
#
#                                      interview_renter person_x  ...  person_y  \
# 0   [[{'content': 'What is your name?', 'role': 'u...   renter  ...  landlord
# 1   [[{'content': 'What is your name?', 'role': 'u...   renter  ...  landlord
# 2   [[{'content': 'What is your name?', 'role': 'u...   renter  ...  landlord
# 3   [[{'content': 'What is your name?', 'role': 'u...   renter  ...  landlord
# 4                                                 NaN      NaN  ...       NaN
# 5   [[{'content': 'What is your name?', 'role': 'u...   renter  ...  landlord
# 6   [[{'content': 'What is your name?', 'role': 'u...   renter  ...  landlord
# 7   [[{'content': 'What is your name?', 'role': 'u...   renter  ...  landlord
# 8   [[{'content': 'What is your name?', 'role': 'u...   renter  ...  landlord
# 9   [[{'content': 'What is your name?', 'role': 'u...   renter  ...  landlord
# 10  [[{'content': 'What is your name?', 'role': 'u...   renter  ...  landlord
# 11  [[{'content': 'What is your name?', 'role': 'u...   renter  ...  landlord
# 12  [[{'content': 'What is your name?', 'role': 'u...   renter  ...  landlord
# 13  [[{'content': 'What is your name?', 'role': 'u...   renter  ...  landlord
# 14  [[{'content': 'What is your name?', 'role': 'u...   renter  ...  landlord
# 15  [[{'content': 'What is your name?', 'role': 'u...   renter  ...  landlord
# 16  [[{'content': 'What is your name?', 'role': 'u...   renter  ...  landlord
# 17  [[{'content': 'What is your name?', 'role': 'u...   renter  ...  landlord
# 18  [[{'content': 'What is your name?', 'role': 'u...   renter  ...  landlord
# 19  [[{'content': 'What is your name?', 'role': 'u...   renter  ...  landlord
# 20  [[{'content': 'What is your name?', 'role': 'u...   renter  ...  landlord
# 21  [[{'content': 'What is your name?', 'role': 'u...   renter  ...  landlord
# 22  [[{'content': 'What is your name?', 'role': 'u...   renter  ...  landlord
# 23  [[{'content': 'What is your name?', 'role': 'u...   renter  ...  landlord
# 24  [[{'content': 'What is your name?', 'role': 'u...   renter  ...  landlord
# 25  [[{'content': 'What is your name?', 'role': 'u...   renter  ...  landlord
# 26  [[{'content': 'What is your name?', 'role': 'u...   renter  ...  landlord
# 27  [[{'content': 'What is your name?', 'role': 'u...   renter  ...  landlord
# 28  [[{'content': 'What is your name?', 'role': 'u...   renter  ...  landlord
# 29  [[{'content': 'What is your name?', 'role': 'u...   renter  ...  landlord
# 30  [[{'content': 'What is your name?', 'role': 'u...   renter  ...  landlord
# 31  [[{'content': 'What is your name?', 'role': 'u...   renter  ...  landlord
# 32  [[{'content': 'What is your name?', 'role': 'u...   renter  ...  landlord
# 33                                                NaN      NaN  ...       NaN
# 34  [[{'content': 'What is your name?', 'role': 'u...   renter  ...  landlord
# 35  [[{'content': 'What is your name?', 'role': 'u...   renter  ...  landlord
# 36  [[{'content': 'What is your name?', 'role': 'u...   renter  ...  landlord
# 37  [[{'content': 'What is your name?', 'role': 'u...   renter  ...  landlord
#
#     successfull_landlord  agent_confusion_landlord  format_change_landlord  \
# 0                    NaN                       NaN                     NaN
# 1                    NaN                       NaN                     NaN
# 2                    NaN                       NaN                     NaN
# 3                    NaN                       NaN                     NaN
# 4                    NaN                       NaN                     NaN
# 5                    NaN                       NaN                     NaN
# 6                    NaN                       NaN                     NaN
# 7                    NaN                       NaN                     NaN
# 8                    NaN                       NaN                     NaN
# 9                    NaN                       NaN                     NaN
# 10                   NaN                       NaN                     NaN
# 11                   NaN                       NaN                     NaN
# 12                   NaN                       NaN                     NaN
# 13                   NaN                       NaN                     NaN
# 14                   NaN                       NaN                     NaN
# 15                   NaN                       NaN                     NaN
# 16                   NaN                       NaN                     NaN
# 17                   NaN                       NaN                     NaN
# 18                   NaN                       NaN                     NaN
# 19                   NaN                       NaN                     NaN
# 20                   NaN                       NaN                     NaN
# 21                   NaN                       NaN                     NaN
# 22                   NaN                       NaN                     NaN
# 23                   NaN                       NaN                     NaN
# 24                   NaN                       NaN                     NaN
# 25                   NaN                       NaN                     NaN
# 26                   NaN                       NaN                     NaN
# 27                   NaN                       NaN                     NaN
# 28                   NaN                       NaN                     NaN
# 29                   NaN                       NaN                     NaN
# 30                   NaN                       NaN                     NaN
# 31                   NaN                       NaN                     NaN
# 32                   NaN                       NaN                     NaN
# 33                   NaN                       NaN                     NaN
# 34                   NaN                       NaN                     NaN
# 35                   NaN                       NaN                     NaN
# 36                   NaN                       NaN                     NaN
# 37                   NaN                       NaN                     NaN
#
#     counterintuitive_landlord  inc_termination_landlord  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
# 10                        NaN                       NaN
# 11                        NaN                       NaN
# 12                        NaN                       NaN
# 13                        NaN                       NaN
# 14                        NaN                       NaN
# 15                        NaN                       NaN
# 16                        NaN                       NaN
# 17                        NaN                       NaN
# 18                        NaN                       NaN
# 19                        NaN                       NaN
# 20                        NaN                       NaN
# 21                        NaN                       NaN
# 22                        NaN                       NaN
# 23                        NaN                       NaN
# 24                        NaN                       NaN
# 25                        NaN                       NaN
# 26                        NaN                       NaN
# 27                        NaN                       NaN
# 28                        NaN                       NaN
# 29                        NaN                       NaN
# 30                        NaN                       NaN
# 31                        NaN                       NaN
# 32                        NaN                       NaN
# 33                        NaN                       NaN
# 34                        NaN                       NaN
# 35                        NaN                       NaN
# 36                        NaN                       NaN
# 37                        NaN                       NaN
#
#     secret_share_landlord  inc_price_acceptance_landlord  \
# 0                     NaN                            NaN
# 1                     NaN                            NaN
# 2                     NaN                            NaN
# 3                     NaN                            NaN
# 4                     NaN                            NaN
# 5                     NaN                            NaN
# 6                     NaN                            NaN
# 7                     NaN                            NaN
# 8                     NaN                            NaN
# 9                     NaN                            NaN
# 10                    NaN                            NaN
# 11                    NaN                            NaN
# 12                    NaN                            NaN
# 13                    NaN                            NaN
# 14                    NaN                            NaN
# 15                    NaN                            NaN
# 16                    NaN                            NaN
# 17                    NaN                            NaN
# 18                    NaN                            NaN
# 19                    NaN                            NaN
# 20                    NaN                            NaN
# 21                    NaN                            NaN
# 22                    NaN                            NaN
# 23                    NaN                            NaN
# 24                    NaN                            NaN
# 25                    NaN                            NaN
# 26                    NaN                            NaN
# 27                    NaN                            NaN
# 28                    NaN                            NaN
# 29                    NaN                            NaN
# 30                    NaN                            NaN
# 31                    NaN                            NaN
# 32                    NaN                            NaN
# 33                    NaN                            NaN
# 34                    NaN                            NaN
# 35                    NaN                            NaN
# 36                    NaN                            NaN
# 37                    NaN                            NaN
#
#     inc_refusal_landlord     _merge
# 0                    NaN       both
# 1                    NaN       both
# 2                    NaN       both
# 3                    NaN       both
# 4                    NaN  left_only
# 5                    NaN       both
# 6                    NaN       both
# 7                    NaN       both
# 8                    NaN       both
# 9                    NaN       both
# 10                   NaN       both
# 11                   NaN       both
# 12                   NaN       both
# 13                   NaN       both
# 14                   NaN       both
# 15                   NaN       both
# 16                   NaN       both
# 17                   NaN       both
# 18                   NaN       both
# 19                   NaN       both
# 20                   NaN       both
# 21                   NaN       both
# 22                   NaN       both
# 23                   NaN       both
# 24                   NaN       both
# 25                   NaN       both
# 26                   NaN       both
# 27                   NaN       both
# 28                   NaN       both
# 29                   NaN       both
# 30                   NaN       both
# 31                   NaN       both
# 32                   NaN       both
# 33                   NaN  left_only
# 34                   NaN       both
# 35                   NaN       both
# 36                   NaN       both
# 37                   NaN       both
#
# [38 rows x 32 columns]

# %%
print(full_to_label.shape)

# determining the name of the file
file_name =  'df_to_label.xlsx'

# saving the excel
full_to_label.to_excel(rand_conv_folder + file_name)
# Out:
# (38, 32)
